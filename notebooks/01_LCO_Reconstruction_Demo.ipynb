# %% [markdown]
# # 01 – LCO Reconstruction Demo\n

# %%
import numpy as np\nfrom src.lco_solver import LCOConfig, lco_solve\nfrom src.utils import set_global_seed\nset_global_seed(42)\nn = 50\nA = np.eye(n)\nd = np.ones(n)\nconfig = LCOConfig(lambdas=np.array([1e4,1e2,10.0,1.0]), epsilons=np.array([1e2,1e2,1e2,1e6]))\nu_hat = lco_solve(A, d, config)\nu_hat[:5]
