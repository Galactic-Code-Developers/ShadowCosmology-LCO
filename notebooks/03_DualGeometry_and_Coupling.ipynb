# %% [markdown]
# # 03 – Dual Geometry and Coupling\n

# %%
import numpy as np\nfrom src.dual_metric import shadow_optical_metric, void_refractivity_tensor, dual_metric\ng = np.eye(4)\ngtilde = shadow_optical_metric(g, 1.05)\nH = np.eye(3)\nN = void_refractivity_tensor(H)\nGdual = dual_metric(g, np.eye(4))\ngtilde, N, Gdual.shape
