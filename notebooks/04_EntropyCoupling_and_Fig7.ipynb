# %% [markdown]
# # 04 – Entropy Coupling and Schematic Figure\n

# %%
import numpy as np\nfrom src.entropy_lagrangian import entropy_gaussian, information_lagrangian\ncov_univ = np.eye(3)\ncov_obs = 2*np.eye(3)\nS_u = entropy_gaussian(cov_univ)\nS_o = entropy_gaussian(cov_obs)\nLinfo = information_lagrangian(S_u, S_o, alpha=1.0, beta=1.0)\nS_u, S_o, Linfo
