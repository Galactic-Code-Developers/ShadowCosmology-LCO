# %% [markdown]
# # 02 – Shadow Transfer Analysis\n

# %%
import numpy as np, csv\nfrom src.shadow_transfer import shadow_transfer\nimport matplotlib.pyplot as plt\nk = []\nP_obs = []\nP_model = []\nwith open('data/example_power_spectra.csv') as f:\n    r = csv.DictReader(f)\n    for row in r:\n        k.append(float(row['k']))\n        P_obs.append(float(row['P_obs']))\n        P_model.append(float(row['P_model']))\nk = np.array(k); P_obs = np.array(P_obs); P_model = np.array(P_model)\nTs = shadow_transfer(P_obs, P_model)\nplt.plot(k, Ts)\nplt.xlabel('k'); plt.ylabel('T_s(k)'); plt.show()
